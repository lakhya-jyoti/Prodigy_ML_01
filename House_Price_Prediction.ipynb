# %% [markdown]
# <a href="https://colab.research.google.com/github/lakhya-jyoti/Prodigyinfotech_ML_Internship/blob/main/House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement a **Linear Regreession** Model to **Predict the Prices of Houses** based on their *Square Footage* and the *number of bedrooms and bathrooms*.
#
# dataset link:
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the training and testing set

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train['SalePrice'].values
# Out:
# array([208500, 181500, 223500, ..., 266500, 142125, 147500])

# %%
features = ['LotArea', 'BedroomAbvGr', 'FullBath', 'HalfBath']
X_train = train[features]
X_test = test[features]

y_train = train['SalePrice']

# %% [markdown]
# Importing the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
y_pred.reshape(-1,1)
# Out:
# array([[133504.18106583],
#        [164074.9093251 ],
#        [241463.34847791],
#        ...,
#        [126627.63638578],
#        [121307.95409242],
#        [234608.65884586]])

# %%
y_pred.tolist()
# Out:
# [133504.1810658276,
#  164074.90932509582,
#  241463.34847791382,
#  235181.10615988716,
#  200813.63332212303,
#  235216.98604851554,
#  195395.44349142455,
#  232610.80141087103,
#  167673.0102599174,
#  128249.40828579593,
#  202204.7944584877,
#  153816.8496332417,
#  143546.7203175668,
#  222626.40694800514,
#  118268.27563098716,
#  239878.1097621501,
#  203391.76594347152,
#  201168.84375253943,
#  205412.45603486174,
#  242229.8733713387,
#  241169.7857527724,
#  204282.56619087764,
#  212542.76844774146,
#  197874.74426265154,
#  240598.96934277518,
#  232896.20961586968,
#  237069.36637715332,
#  207307.89316386293,
#  207679.73928237543,
#  209677.59671736573,
#  238348.32178335753,
#  130532.67392578484,
#  207513.06042365154,
#  230072.7880946158,
#  226796.3019012317,
#  200536.3796372672,
#  234910.70273895608,
#  234421.43153038702,
#  233327.0949272209,
#  233327.0949272209,
#  234038.16908367455,
#  233097.1374591934,
#  182309.0696600569,
#  230942.3865896506,
# ...

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
Result = test[['Id']]
Result
# Out:
#         Id
# 0     1461
# 1     1462
# 2     1463
# 3     1464
# 4     1465
# ...    ...
# 1454  2915
# 1455  2916
# 1456  2917
# 1457  2918
# 1458  2919
#
# [1459 rows x 1 columns]

# %%
Result.loc[range(len(Result)), 'SalePrice'] = y_pred  # Use .loc for efficient assignment

# %%
Result
# Out:
#         Id      SalePrice
# 0     1461  133504.181066
# 1     1462  164074.909325
# 2     1463  241463.348478
# 3     1464  235181.106160
# 4     1465  200813.633322
# ...    ...            ...
# 1454  2915  143964.231749
# 1455  2916  143895.733780
# 1456  2917  126627.636386
# 1457  2918  121307.954092
# 1458  2919  234608.658846
#
# [1459 rows x 2 columns]

# %%
Result.to_csv('PredictionResult.csv')

# %%
# Create a new DataFrame with random values for features
new_data = pd.DataFrame({
    'LotArea': [20000],
    'BedroomAbvGr': [3],
    'FullBath': [2],
    'HalfBath': [1]
})

# Predict the SalePrice using the trained model
predicted_price = model.predict(new_data)

print(f"Predicted SalePrice: {predicted_price[0]}")
# Out:
# Predicted SalePrice: 251526.02633415075

# %%
#predict the saleprice using attributes from the test by considering one random id

# Get a random ID from the test dataset
random_id = test['Id'].sample().values[0]

# Get the corresponding row from the test dataset
random_row = test[test['Id'] == random_id]

# Extract the features for the random row
random_features = random_row[['LotArea', 'BedroomAbvGr', 'FullBath', 'HalfBath']]

# Predict the SalePrice using the trained model
predicted_price = model.predict(random_features)

print(f"Predicted SalePrice for ID {random_id}: {predicted_price[0]}")
# Out:
# Predicted SalePrice for ID 2029: 222626.40694800514

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_train, model.predict(X_train), color='blue', label='Training Data')
# The test DataFrame likely doesn't have 'SalePrice'. Replace this with the predictions (y_pred) for the test data.
plt.scatter(y_pred, y_pred, color='red', label='Test Data')
plt.xlabel('Actual SalePrice')
plt.ylabel('Predicted SalePrice')
plt.title('Actual vs. Predicted SalePrice')
plt.legend()
plt.show()
